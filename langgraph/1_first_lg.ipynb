# %%
from langgraph.prebuilt import create_react_agent
from langchain_core.messages import HumanMessage
def calculate_expression(expression: str) -> str:
    """ Caluclates the result of a mathematical expression using a React agent."""
    return "Done"
react_agent = create_react_agent(model="gpt-5-mini", tools=[])
result = react_agent.invoke({"messages": [HumanMessage(content="What is 5 + 3 or 5 - 3?")]})
print(result)

result["messages"][-1]
#result["messages"][-1].content
# Out:
# /var/folders/qn/rvyhkgdd7fz5qvcxdc4jvpxr0000gn/T/ipykernel_3458/63798459.py:6: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   react_agent = create_react_agent(model="gpt-5-mini", tools=[])
# ...
